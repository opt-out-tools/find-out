# %%
from spacy import displacy
import spacy
import json


corpus = json.load(open("../../data/raw/rapeglish/rape_threat_generator_data.json"))

nlp = spacy.load("en_core_web_md")
docs = [nlp(tweet) for tweet in corpus[1]]

displacy.render(docs[0], style='dep', jupyter=True, options={'distance': 90})
print("here")
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d8242da444a44e87b3d915dc0091fde9-0" class="displacy" width="1130" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">’d</tspan>
# ...
